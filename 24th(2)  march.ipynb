# %%
#convernt  all the list elemneent convernt in upper case

# %% [raw]
# list=["hello","aniket","python","java","analytics"]

# %%
for i in list:
    print(i.upper())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 for i in list:
#       2     print(i.upper())
#
# TypeError: 'type' object is not iterable

# %%
list2=[i.upper() for i in list]

# %%
list1 =[4,16,25,64,81]
print(list1)
# Out:
# [4, 16, 25, 64, 81]

# %%
import math

# %%
#num = list(map(lambda j: math.sqrt(j),list1))
num = list(map(lambda j: math.sqrt(j), list1))

# %%
class sample:
    def mymethod(self,a,b):
        print(a+b)
    def mymethod(self,a,b,c):
        print(a*b*c)

# %%
s = sample()

# %%
s.mymethod(20,5,8)
# Out:
# 800

# %%
# multilevel inheritance

# %%
class A:
    def feature(self):
        print("hello feature of A")
    def feature2(self):
        print("anotehr feature of class A")

# %%
class B(A):
    def featureB(self):
        print("hello feature of B")
    def featureTwo(self):
        print("anotehr feature of class B")

# %%
class C(B):
    def featureC(self):
        print("hello feature of C")
    def Cfeature(self):
        print("anotehr feature of class C")

# %%
a=A()

# %%
b=B()

# %%
c=C()

# %%
c.Cfeature()
# Out:
# anotehr feature of class C

# %%
class A:
    def __init__(self):
        print("constuvtorrrrrrrrrr of A")
    def feature(self):
        print("hello feature of A")
    def feature2(self):
        print("anotehr feature of class A")

# %%
class B(A):
    def __init__(self):
        print("constuvtorrrrr of B")
    def feature(self):
        print("hello feature of B")
    def feature2(self):
        print("anotehr feature of class B")

# %%
class c(B):
    def __init__(self):
        print("constuvtorr of C")
    def feature(self):
        print("hello feature of C")
    def feature2(self):
        print("anotehr feature of class C")

# %%
a=A()
b=B()
c=C()
# Out:
# constuvtorrrrrrrrrr of A
# constuvtorrrrr of B

# %%
c=C()

# %%
c.featureB()
# Out:
# hello feature of B

# %%
### abstraction

# %%
from abc import ABC,abstractmethod

# %%
M.mymethod()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 M.mymethod()
#
# NameError: name 'M' is not defined

# %%
class MyClass(ABC):  # Abstract class
    @abstractmethod
    def mymethod(self):
        pass  # Abstract method should not have an implementation here

# Create a subclass that implements the abstract method
class ChildClass(MyClass):
    def mymethod(self):
        print("Aniket Desai")

# %%
s1 = mysample()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 s1 = mysample()
#
# NameError: name 'mysample' is not defined

# %%
s1.mymethod()

# %%
s1.myfun()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 s1.myfun()
#
# NameError: name 's1' is not defined

# %%
s1.mymethod()

# %%
list=[12,56,89,64,12,66]
