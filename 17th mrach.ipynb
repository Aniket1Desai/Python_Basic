# %%
def myfunction():
    print("hello my 1st function")

# %%
myfunction()
# Out:
# hello my 1st function

# %%
def add(a,b,c=90):
    print(a+b+c)

# %%
add(52,5)
# Out:
# 147

# %%
def mymethod(*a):       # * args
                        # ** keyargs
    print(a)

# %%
z=mymethod(25,85,89,4)
num_dict={i:i**2 for i in range(len({z}))}
# Out:
# (25, 85, 89, 4)

# %%
type(z)
# Out:
# NoneType

# %%
 def dict(**x):                 #key lenght
     print(x)

# %%
dict(name='aniket',age=21,city='bharuch')
# Out:
# {'name': 'aniket', 'age': 21, 'city': 'bharuch'}

# %%
num_dict={i:i**2 for i in range(1,11)}

# %%
def generate_squares(*n):
   for i in n:
       print(i*i)

generate_squares(52,85,74,50)
# Out:
# 2704
# 7225
# 5476
# 2500

# %% [markdown]
# #lambda

# %%
num=lambda x:x+10

# %%
num(5)
# Out:
# 15

# %%
num=lambda x,y:x+y

# %%
num(10,52)
# Out:
# 62

# %%
list1=[20,21,22,23,24,25]

# %%
squ=list(map(lambda x:x**2,list1))

# %%
squ
# Out:
# [400, 441, 484, 529, 576, 625]

# %%
squ=list(filter(lambda x:x%2==0,list1))
squ=list(filter(lambda x:x>20,list1))
squ=list(filter(lambda x:x/2,list1))

# %%
print(squ)
# Out:
# [20, 21, 22, 23, 24, 25]

# %%
l=[78,89,23,56]
sum(l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 2
#       1 l=[78,89,23,56]
# ----> 2 sum(l)
#
# TypeError: 'int' object is not callable

# %%
from functools import reduce

# %%
sum=reduce(lambda x,y:x+y,l)

# %%
sum
# Out:
# 246

# %%
var1=[("aniket",20),("karan",12),("aryan",25),("sujal",30)]

# %%
var1
# Out:
# [('aniket', 20), ('karan', 12), ('aryan', 25), ('sujal', 30)]

# %%
type(var1)
# Out:
# list

# %%
sorted_var1 = sorted(var1, key=lambda x: x[1])
var1.sort(key=lambda x:x[1])

# %%
print(sorted_var1)
var1
# Out:
# [('karan', 12), ('aniket', 20), ('aryan', 25), ('sujal', 30)]
# [('karan', 12), ('aniket', 20), ('aryan', 25), ('sujal', 30)]

# %%
help(list.sort)
# Out:
# Help on method_descriptor:
#
# sort(self, /, *, key=None, reverse=False) unbound builtins.list method
#     Sort the list in ascending order and return None.
#
#     The sort is in-place (i.e. the list itself is modified) and stable (i.e. the
#     order of two equal elements is maintained).
#
#     If a key function is given, apply it once to each list item and sort them,
#     ascending or descending, according to their function values.
#
#     The reverse flag can be set to sort in descending order.

# %%
l2=['banana','pineapple','apple','grapes']

# %%
longest_word = max(l2, key=len)
sorted_var1 = max(l2, key=lambda x:len(x))

# %%
print(sorted_var1)
# Out:
# pineapple

# %%
help(max)
# Out:
# Help on built-in function max in module builtins:
#
# max(...)
#     max(iterable, *[, default=obj, key=func]) -> value
#     max(arg1, arg2, *args, *[, key=func]) -> value
#
#     With a single iterable argument, return its biggest item. The
#     default keyword-only argument specifies an object to return if
#     the provided iterable is empty.
#     With two or more arguments, return the largest argument.

# %%
min(l2)
# Out:
# 'apple'
