# %%
# generator
# Yield (It will hold the values after excution)
# 1. Lazy execution
# 2. Memory utilizzation in a  efficient way

# %%
def generator():
    print("Hello 1st Yield")
    yield 1
    print("Hello 2nd Yield")
    yield 2
    print("Hello 3rd Yield")
    yield 3

# %%
gen = generator()

# %%
next(gen)
# Out:
# Hello 1st Yield
# 1

# %%
next(gen)
# Out:
# Hello 2nd Yield
# 2

# %%
next(gen)
# Out:
# Hello 3rd Yield
# 3

# %%
next(gen)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 next(gen)
#
# StopIteration:

# %%
# Generator Expression
gen_exp = (i*i for i in range(0,5))

# %%
next(gen_exp)
# Out:
# 0

# %%
next(gen_exp)
# Out:
# 1

# %%
next(gen_exp)
# Out:
# 4

# %%
next(gen_exp)  #and so on
# Out:
# 9

# %%
def Nouter(fun):  #Decorators concept
    def inner():
        print("Hello Outer")
        fun()
    return inner
X = outer(normal)
X()
# Out:
# Hello Outer
# Hello Normal

# %%
def normal():
    print("Hello Normal")

# %%
@outer  # decorator 2  It needs more practice.
def normal():
    print("Hello Normal")
nor = normal()
# Out:
# Hello Outer
# Hello Normal

# %%
def generator(): #print 1 to 5 using generator
    for i in range(1,6):
        yield i

# %%
gen = generator()

# %%
next(gen)
# Out:
# 1

# %%
next(gen)
# Out:
# 2

# %%
next(gen)
# Out:
# 3

# %%
next(gen)
# Out:
# 4

# %%
next(gen)
# Out:
# 5

# %%
next(gen)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 next(gen)
#
# StopIteration:
