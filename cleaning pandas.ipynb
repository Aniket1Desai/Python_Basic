# %%
import pandas as pd

# %%
dataa=pd.DataFrame({'group':['a','a','a','b','b','b','c','c','c'],'ounces':[4,3,12,6,7.5,8.,3,5,6]})

# %%
dataa
# Out:
#   group  ounces
# 0     a     4.0
# 1     a     3.0
# 2     a    12.0
# 3     b     6.0
# 4     b     7.5
# 5     b     8.0
# 6     c     3.0
# 7     c     5.0
# 8     c     6.0

# %%
dataa.sort_values(by=['ounces'],ascending=True)
# Out:
#   group  ounces
# 1     a     3.0
# 6     c     3.0
# 0     a     4.0
# 7     c     5.0
# 3     b     6.0
# 8     c     6.0
# 4     b     7.5
# 5     b     8.0
# 2     a    12.0

# %%
dataa.sort_values(by=['ounces'],ascending=True,inplace=False)
# Out:
#   group  ounces
# 1     a     3.0
# 6     c     3.0
# 0     a     4.0
# 7     c     5.0
# 3     b     6.0
# 8     c     6.0
# 4     b     7.5
# 5     b     8.0
# 2     a    12.0

# %%
dataa.sort_values(by=['group','ounces'],ascending=[True,False],inplace=False)
# Out:
#   group  ounces
# 2     a    12.0
# 0     a     4.0
# 1     a     3.0
# 5     b     8.0
# 4     b     7.5
# 3     b     6.0
# 8     c     6.0
# 7     c     5.0
# 6     c     3.0

# %%
dataa.assign(new = [10,25,85,96,71,74,35,22,85])    # assign new columns
# Out:
#   group  ounces  new
# 0     a     4.0   10
# 1     a     3.0   25
# 2     a    12.0   85
# 3     b     6.0   96
# 4     b     7.5   71
# 5     b     8.0   74
# 6     c     3.0   35
# 7     c     5.0   22
# 8     c     6.0   85

# %%
dataf=pd.read_csv("C:\\Users\\XYZ\\Downloads\\train.csv")

# %%
dataf
# Out:
#        age          workclass  fnlwgt    education  education.num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital.status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
dataf.info
# Out:
# <bound method DataFrame.info of        age          workclass  fnlwgt    education  education.num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital.status          occupation    relationship    race  \
# ...

# %%
dataf.shape # raws and column
# Out:
# (32561, 15)

# %%
dataf.size # total data
# Out:
# 488415

# %%
dataf.describe()  # summury
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
dataf.info()        #object = string
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       30725 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      30718 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  31978 non-null  object
#  14  target          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
dataf.isnull().sum()     #find the null values in each column and count
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     583
# target               0
# dtype: int64

# %%
dataf.isna().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     583
# target               0
# dtype: int64

# %%
dataf['workclass'].mode()
# Out:
# 0     Private
# Name: workclass, dtype: object

# %%
dataf['workclass'].value_counts()
# Out:
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64

# %%
dataf.workclass.fillna("private",inplace=True)
# Out:
# C:\Users\XYZ\AppData\Local\Temp\ipykernel_10612\3080768888.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataf.workclass.fillna("private",inplace=True)

# %%
dataf.isna().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     583
# target               0
# dtype: int64

# %%
dataf['native.country'].value_counts()
# Out:
# native.country
# United-States                 29170
# Mexico                          643
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# ...

# %%
dataf["native.country"].fillna("United-state",inplace=True)
# Out:
# C:\Users\XYZ\AppData\Local\Temp\ipykernel_10612\3665402696.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataf["native.country"].fillna("United-state",inplace=True)

# %%
dataf.isna().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country       0
# target               0
# dtype: int64

# %%
dataf['occupation'].value_counts()
# Out:
# occupation
# Prof-specialty       4140
# Craft-repair         4099
# Exec-managerial      4066
# Adm-clerical         3770
# Sales                3650
# Other-service        3295
# Machine-op-inspct    2002
# Transport-moving     1597
# Handlers-cleaners    1370
# Farming-fishing       994
# Tech-support          928
# Protective-serv       649
# Priv-house-serv       149
# Armed-Forces            9
# Name: count, dtype: int64

# %%
dataf.occupation.fillna("Prof-specialty",inplace=True)
# Out:
# C:\Users\XYZ\AppData\Local\Temp\ipykernel_10612\2645191320.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataf.occupation.fillna("Prof-specialty",inplace=True)

# %%
dataf.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# target            0
# dtype: int64

# %%
dataf.iloc[:,0]
# Out:
# 0        39
# 1        50
# 2        38
# 3        53
# 4        28
#          ..
# 32556    27
# 32557    40
# 32558    58
# 32559    22
# 32560    52
# Name: age, Length: 32561, dtype: int64

# %%
dataf.iloc[0:3,0]    # dive fissrt 3 values
# Out:
# 0    39
# 1    50
# 2    38
# Name: age, dtype: int64

# %%
dataf.iloc[[2,100,50],0]     # give ranndom values
# Out:
# 2      38
# 100    76
# 50     25
# Name: age, dtype: int64

# %%
dataf.loc[:,["occupation","relationship","sex"]]
# Out:
#                occupation    relationship      sex
# 0            Adm-clerical   Not-in-family     Male
# 1         Exec-managerial         Husband     Male
# 2       Handlers-cleaners   Not-in-family     Male
# 3       Handlers-cleaners         Husband     Male
# 4          Prof-specialty            Wife   Female
# ...                   ...             ...      ...
# 32556        Tech-support            Wife   Female
# 32557   Machine-op-inspct         Husband     Male
# 32558        Adm-clerical       Unmarried   Female
# 32559        Adm-clerical       Own-child     Male
# 32560     Exec-managerial            Wife   Female
#
# [32561 rows x 3 columns]

# %%
dataf['relationship'] ==' Wife'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 32556     True
# 32557    False
# 32558    False
# 32559    False
# 32560     True
# Name: relationship, Length: 32561, dtype: bool

# %%
dataf[(dataf['sex']==' Male') & (dataf['age']>=31)]
# Out:
#        age          workclass  fnlwgt   education  education.num  \
# 0       39          State-gov   77516   Bachelors             13
# 1       50   Self-emp-not-inc   83311   Bachelors             13
# 2       38            Private  215646     HS-grad              9
# 3       53            Private  234721        11th              7
# 7       52   Self-emp-not-inc  209642     HS-grad              9
# ...    ...                ...     ...         ...            ...
# 32551   32            Private   34066        10th              6
# 32552   43            Private   84661   Assoc-voc             11
# 32553   32            Private  116138     Masters             14
# 32554   53            Private  321865     Masters             14
# 32557   40            Private  154374     HS-grad              9
#
#             marital.status          occupation    relationship  \
# 0            Never-married        Adm-clerical   Not-in-family
# ...

# %%
dataf.loc[(dataf["sex"]==" Male") & (dataf["age"] >= 31)]
# Out:
#        age          workclass  fnlwgt   education  education.num  \
# 0       39          State-gov   77516   Bachelors             13
# 1       50   Self-emp-not-inc   83311   Bachelors             13
# 2       38            Private  215646     HS-grad              9
# 3       53            Private  234721        11th              7
# 7       52   Self-emp-not-inc  209642     HS-grad              9
# ...    ...                ...     ...         ...            ...
# 32551   32            Private   34066        10th              6
# 32552   43            Private   84661   Assoc-voc             11
# 32553   32            Private  116138     Masters             14
# 32554   53            Private  321865     Masters             14
# 32557   40            Private  154374     HS-grad              9
#
#             marital.status          occupation    relationship  \
# 0            Never-married        Adm-clerical   Not-in-family
# ...
