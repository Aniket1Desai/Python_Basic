# %% [markdown]
# #tuple

# %%
fruits='mango','apple','cherry','banana'

# %%
type(fruits)
# Out:
# tuple

# %%
fruit='mango'

# %%
type(fruit)
# Out:
# str

# %%
print(fruits)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 print(fruits)
#
# TypeError: print() takes 0 positional arguments but 1 was given

# %%
fruits[0]
# Out:
# 'mango'

# %%
fruits[1]
# Out:
# 'apple'

# %%
fruits.count('banana')
# Out:
# 1

# %%
fruits.index('banana')
# Out:
# 3

# %% [markdown]
# #dictionary

# %%
student={'name':'aniket','age':20,'city':'vadodara','course':'data analytics','name':"sujal"} #duplicate mot allowed

# %%
print(student)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 print(student)
#
# TypeError: print() takes 0 positional arguments but 1 was given

# %%
student['name']
# Out:
# 'sujal'

# %%
student['age']
# Out:
# 20

# %%
student
# Out:
# {'name': 'sujal', 'age': 20, 'city': 'vadodara', 'course': 'data analytics'}

# %%
student['city']='surat'

# %% [markdown]
# #method

# %%
student.items()
# Out:
# dict_items([('name', 'sujal'), ('age', 20), ('city', 'surat'), ('course', 'data analytics')])

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'city', 'course'])

# %%
student.values()
# Out:
# dict_values(['sujal', 20, 'surat', 'data analytics'])

# %%
student.pop("age")
# Out:
# 20

# %%
student
# Out:
# {'name': 'sujal', 'city': 'surat', 'course': 'data analytics'}

# %%
student.popitem()
# Out:
# ('course', 'data analytics')

# %%
student.update({"number":1234567891})

# %%
clear()

# %%
student.setdefault('Roll number')

# %%
student
# Out:
# {'name': 'sujal', 'city': 'surat', 'number': 1234567891, 'Roll number': None}

# %%
student.update({'Roll number':2101202003})

# %%
student.fromkeys('Roll number')
# Out:
# {'R': None,
#  'o': None,
#  'l': None,
#  ' ': None,
#  'n': None,
#  'u': None,
#  'm': None,
#  'b': None,
#  'e': None,
#  'r': None}

# %%
keys=['one','two','three']

# %%
values=[1,2,3,4]

# %%
lib={}

# %%
lib.fromkeys(keys,values)
# Out:
# {'one': [1, 2, 3, 4], 'two': [1, 2, 3, 4], 'three': [1, 2, 3, 4]}

# %%
a=zip(keys,values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 a=zip(keys,values)
#
# NameError: name 'keys' is not defined

# %%
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(a)
#
# NameError: name 'a' is not defined

# %%
num_dict={i:i**2 for i in range(1,11)}

# %%
num_dict
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
num_dict=[i**2 for i in range(1,11)]

# %%
nested_dict={'student1':{'name':'aniket','age':25},'student':{'city':'surat','number':2514593}}

# %%
nested_dict
# Out:
# {'student1': {'name': 'aniket', 'age': 25},
#  'student': {'city': 'surat', 'number': 2514593}}

# %%
x={'one':[1,2,5,3,8],'two':[52,85,75]}

# %%
x
# Out:
# {'one': [1, 2, 5, 3, 8], 'two': [52, 85, 75]}

# %%
x['one'][0]
# Out:
# 1

# %% [markdown]
# #function

# %%
def add(a,b):
    print(a+b)

# %%
add(10,5)
# Out:
# 15

# %%
def Display():
    print("helloo my name is aniket")

# %%
Display()
# Out:
# helloo my name is aniket
