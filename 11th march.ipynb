# %%
x="       hello world@                  "

# %%
x
# Out:
# 'hello world@                  '

# %%
x.islower()
# Out:
# True

# %%
x.isupper()
# Out:
# False

# %%
x.isprintable()
# Out:
# True

# %%
y="aniket\n"
q=" "

# %%
y.isprintable()
# Out:
# False

# %%
q.isspace()
# Out:
# True

# %%
y.join("ABC")
# Out:
# 'Aaniket\nBaniket\nC'

# %%
y.ljust(10)
# Out:
# 'aniket\n   '

# %%
x.strip()

x.lstrip()
x.rstrip()
# Out:
# '       hello world@'

# %%
print(x)
# Out:
#        hello world@

# %%
x.rstrip()
# Out:
# '       hello world@'

# %%
x.lstrip()
# Out:
# 'hello world@                  '

# %%
a="hello my name is aniket"

# %%
a.removeprefix("is")
# Out:
# 'hello my name is aniket'

# %%
a.removesuffix("aniket")
# Out:
# 'hello my name is '

# %%
a.replace("i","I")
# Out:
# 'hello my name Is anIket'

# %%
a.split(" ",3)
# Out:
# ['hello', 'my', 'name', 'is aniket']

# %%
x.rsplit(" ",2)
# Out:
# ['       hello world@                ', '', '']

# %%
a.splitline()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 a.splitline()
#
# AttributeError: 'str' object has no attribute 'splitline'

# %%
a.splitlines()
# Out:
# ['hello my name is aniket']

# %%
color=["yellow","red","pink","black","blue"]

# %%
print(color)
# Out:
# ['yellow', 'red', 'pink', 'black', 'blue']

# %%
color[1]
# Out:
# 'red'

# %%
color[2]='baby pinK'

# %%
print(color)
# Out:
# ['yellow', 'red', 'baby pinK', 'black', 'blue']

# %%
color.append("white")

# %%
print(color)
# Out:
# ['yellow', 'red', 'baby pinK', 'black', 'blue', 'white']

# %%
color.count("b")
# Out:
# 0

# %%
color.insert(2,"maroon")

# %%
print(color)
# Out:
# ['yellow', 'red', 'baby pinK', 'black', 'blue', 'white']

# %%
color.pop(2)
# Out:
# 'maroon'

# %%
color.remove("maroon")

# %%
color.sort(reverse=True)

# %%
print(color)
# Out:
# ['yellow', 'white', 'red', 'blue', 'black', 'baby pinK']

# %%
l1=["hello","my","name","is","aniket"]

# %%
color.extend(l1)

# %%
print(color)
# Out:
# ['yellow', 'white', 'red', 'blue', 'black', 'baby pinK', 'hello', 'my', 'name', 'is', 'aniket']

# %%
del l1

# %%
l1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 l1
#
# NameError: name 'l1' is not defined

# %%
color.clear()

# %%
color
# Out:
# ['hello', 'my', 'name', 'is', 'aniket']

# %%
color=l1.copy()

# %%
print(color)
print(l1)
# Out:
# ['hello', 'my', 'name', 'is', 'aniket']
# ['hello', 'my', 'name', 'is', 'aniket', 'desai']

# %%
l1.append("desai")

# %%
color1=color

# %%
print(color1)
# Out:
# ['hello', 'my', 'name', 'is', 'aniket']

# %%
color1.append("21")

# %%
print(color1)
# Out:
# ['hello', 'my', 'name', 'is', 'aniket', '21']

# %%
print(color)
print(l1)
# Out:
# ['hello', 'my', 'name', 'is', 'aniket', '21']
# ['hello', 'my', 'name', 'is', 'aniket', 'desai']

# %%
l=[1,2,3,5,8,4,6,7]

# %%
li=[5,8,9,6,4,10,7,45]

# %%
 l3=[]

# %%
for j in range(len(l)):
    sum=l[j]+li[j]
    l3.append(sum)
print(l3)
# Out:
# [6, 10, 12, 11, 12, 14, 13, 52]
